# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../artifacts/raw.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.duplicated().sum()
# Out:
# np.int64(1435)

# %%
new_df=df.drop_duplicates()

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_col=new_df.columns

# %%
numerical_col=[]
categorical_col=[]

# %%
for col in df_col:
    if new_df[col].dtype == "object" :
        categorical_col.append(col)
    else:
        numerical_col.append(col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (2772, 7)

# %%
new_df.shape
# Out:
# (1337, 7)

# %%
new_df.sample(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 898    18  female  40.26         0     no  southeast   1634.5734
# 72     53  female  28.10         3     no  southwest  11741.7260
# 298    31    male  34.39         3    yes  northwest  38746.3551
# 1322   62    male  38.83         0     no  southeast  12981.3457
# 208    63  female  31.80         0     no  southwest  13880.9490

# %%
plt.figure(figsize=(3,3))
plt.hist(x=new_df['age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
numerical_col
# Out:
# ['age', 'bmi', 'children', 'charges']

# %% [markdown]
# Numerical col plot

# %%
for colm in numerical_col:
    plt.figure(figsize=(3,4))
    sns.kdeplot(data=new_df, x=colm, fill=True, hue='smoker')

# %%
new_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(4,4))
sns.heatmap(data=new_df[numerical_col].corr(),annot=True)
# Out:
# <Axes: >

# %%
for col in numerical_col:
    plt.figure(figsize=(8,2))
    sns.boxplot(data=new_df, x=col)

# %% [markdown]
# catagorical col plot

# %%
new_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=new_df, x='age', y='charges', hue='smoker')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(data=new_df, x='bmi', y='charges', hue='smoker')
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.barplot(data=new_df, x='sex', y='charges')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.barplot(data=new_df, x='children', y='charges')
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
sns.barplot(data=new_df, x='region', y='charges', hue='sex')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
new_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
new_df['region'].value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>
